# %%
import mlrose_hiive
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_run_stats_rhc1 = pd.read_csv("out/RHC1_Queens/rhc__RHC1_Queens__run_stats_df.csv")
df_run_stats_rhc2 = pd.read_csv("out/RHC2_Queens/rhc__RHC2_Queens__run_stats_df.csv")
df_run_stats_rhc3 = pd.read_csv("out/RHC3_Queens/rhc__RHC3_Queens__run_stats_df.csv")
df_run_stats_rhc4 = pd.read_csv("out/RHC4_Queens/rhc__RHC4_Queens__run_stats_df.csv")
df_run_stats_rhc5 = pd.read_csv("out/RHC5_Queens/rhc__RHC5_Queens__run_stats_df.csv")

# %%
df_run_stats_sa1 = pd.read_csv("out/SA1_Queens/sa__SA1_Queens__run_stats_df.csv")
df_run_stats_sa2 = pd.read_csv("out/SA2_Queens/sa__SA2_Queens__run_stats_df.csv")
df_run_stats_sa3 = pd.read_csv("out/SA3_Queens/sa__SA3_Queens__run_stats_df.csv")
df_run_stats_sa4 = pd.read_csv("out/SA4_Queens/sa__SA4_Queens__run_stats_df.csv")
df_run_stats_sa5 = pd.read_csv("out/SA5_Queens/sa__SA5_Queens__run_stats_df.csv")

# %%
df_run_stats_ga1 = pd.read_csv("out/GA1_Queens/ga__GA1_Queens__run_stats_df.csv")
df_run_stats_ga2 = pd.read_csv("out/GA2_Queens/ga__GA2_Queens__run_stats_df.csv")
df_run_stats_ga3 = pd.read_csv("out/GA3_Queens/ga__GA3_Queens__run_stats_df.csv")
df_run_stats_ga4 = pd.read_csv("out/GA4_Queens/ga__GA4_Queens__run_stats_df.csv")
df_run_stats_ga5 = pd.read_csv("out/GA5_Queens/ga__GA5_Queens__run_stats_df.csv")

# %%
data_rhc = [{'Problem Size': 4, 'Fitness': df_run_stats_rhc1['Fitness'].max()},
           {'Problem Size': 8, 'Fitness': df_run_stats_rhc2['Fitness'].max()},
           {'Problem Size': 16, 'Fitness': df_run_stats_rhc3['Fitness'].max()},
           {'Problem Size': 32, 'Fitness': df_run_stats_rhc4['Fitness'].max()},
           {'Problem Size': 64, 'Fitness': df_run_stats_rhc5['Fitness'].max()}]
df_rhc = pd.DataFrame(data_rhc)

data_sa = [{'Problem Size': 4, 'Fitness': df_run_stats_sa1['Fitness'].max()},
           {'Problem Size': 8, 'Fitness': df_run_stats_sa2['Fitness'].max()},
           {'Problem Size': 16, 'Fitness': df_run_stats_sa3['Fitness'].max()},
           {'Problem Size': 32, 'Fitness': df_run_stats_sa4['Fitness'].max()},
           {'Problem Size': 64, 'Fitness': df_run_stats_sa5['Fitness'].max()}]
df_sa = pd.DataFrame(data_sa)

data_ga = [{'Problem Size': 4, 'Fitness': df_run_stats_ga1['Fitness'].max()},
           {'Problem Size': 8, 'Fitness': df_run_stats_ga2['Fitness'].max()},
           {'Problem Size': 16, 'Fitness': df_run_stats_ga3['Fitness'].max()},
           {'Problem Size': 32, 'Fitness': df_run_stats_ga4['Fitness'].max()},
           {'Problem Size': 64, 'Fitness': df_run_stats_ga5['Fitness'].max()}]
df_ga = pd.DataFrame(data_ga)

# %%
plt.plot(df_rhc['Problem Size'], df_rhc['Fitness'], label='RHC', color='green')
plt.plot(df_sa['Problem Size'], df_sa['Fitness'], label='SA', color='red')
plt.plot(df_ga['Problem Size'], df_ga['Fitness'], label='GA', color='blue')
#plt.plot(df_mmc['Problem Size'], df_mmc['Fitness'], label='MIMIC', color='orange')
plt.legend(loc="best")
plt.xlabel("Problem Size")
plt.ylabel("Fitness")
plt.grid()
plt.title("Fitness vs Problem Size Queens")
plt.savefig("Fitness vs Problem Size Queens")

# %%
df_run_stats_sa = pd.read_csv("out/SA_Queens/sa__SA_Queens__run_stats_df.csv")
df_run_stats_sa
# Out:
#      Unnamed: 0  Iteration  Fitness  FEvals       Time  \
# 0             0          0     29.0       0   0.005954
# 1             1          1     29.0       2   0.048163
# 2             2          2     29.0       3   0.097073
# 3             3          4     30.0       7   0.168067
# 4             4          8     26.0      12   0.223508
# ..          ...        ...      ...     ...        ...
# 331         331        256     32.0     509  18.695671
# 332         332        512     27.0    1010  23.756304
# 333         333       1024     21.0    1873  31.873199
# 334         334       2048      4.0    3001  47.586853
# 335         335       4096      1.0    5094  89.279866
#
#                                                  State schedule_type  \
# 0    [6, 19, 28, 14, 10, 7, 28, 20, 6, 25, 18, 22, ...     geometric
# 1    [6, 19, 28, 14, 10, 7, 28, 20, 6, 25, 18, 26, ...     geometric
# 2    [6, 19, 28, 14, 10, 7, 28, 20, 6, 25, 18, 26, ...     geometric
# ...

# %%
df_popsize_sa_1 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==1)]
df_popsize_sa_2 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==2)]
df_popsize_sa_3 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==3)]
df_popsize_sa_4 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==4)]
df_popsize_sa_5 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==5)]
df_popsize_sa_6 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==6)]
df_popsize_sa_7 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==7)]
df_popsize_sa_8 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==8)]
df_popsize_sa_9 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==9)]
df_popsize_sa_10 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==10)]
df_popsize_sa_50 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==50)]
df_popsize_sa_100 = df_run_stats_sa.loc[(df_run_stats_sa['schedule_type']=='exponential') & (df_run_stats_sa['schedule_init_temp']==100)]

# %%
plt.plot(df_popsize_sa_1['Iteration'], df_popsize_sa_1['Fitness'], label='1')
plt.plot(df_popsize_sa_2['Iteration'], df_popsize_sa_2['Fitness'], label='2')
plt.plot(df_popsize_sa_3['Iteration'], df_popsize_sa_3['Fitness'], label='3')
plt.plot(df_popsize_sa_4['Iteration'], df_popsize_sa_4['Fitness'], label='4')
plt.plot(df_popsize_sa_5['Iteration'], df_popsize_sa_5['Fitness'], label='5')
plt.plot(df_popsize_sa_6['Iteration'], df_popsize_sa_6['Fitness'], label='6')
plt.plot(df_popsize_sa_7['Iteration'], df_popsize_sa_7['Fitness'], label='7')
plt.plot(df_popsize_sa_8['Iteration'], df_popsize_sa_8['Fitness'], label='8')
plt.plot(df_popsize_sa_9['Iteration'], df_popsize_sa_9['Fitness'], label='9')
plt.plot(df_popsize_sa_10['Iteration'], df_popsize_sa_10['Fitness'], label='10')
plt.plot(df_popsize_sa_50['Iteration'], df_popsize_sa_50['Fitness'], label='50')
plt.plot(df_popsize_sa_100['Iteration'], df_popsize_sa_100['Fitness'], label='100')
plt.legend(loc="best")
plt.xlabel("Iteration")
plt.ylabel("Fitness")
plt.grid()
plt.title("Fitness vs Iteration with Temperature Queens (sa)")
plt.savefig("Fitness vs Iteration with Temperature Queens (sa)")
